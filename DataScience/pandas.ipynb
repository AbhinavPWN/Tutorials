# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/rj7shakya/python_ml/main/cleaned_imdb.csv")
df.iloc[0][2]
# Out:
# 'James Cameron'

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'color', 'director_name', 'num_critic_for_reviews',
#        'duration', 'director_facebook_likes', 'actor_3_facebook_likes',
#        'actor_2_name', 'actor_1_facebook_likes', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'cast_total_facebook_likes', 'actor_3_name', 'facenumber_in_poster',
#        'plot_keywords', 'movie_imdb_link', 'num_user_for_reviews', 'language',
#        'country', 'content_rating', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'imdb_score', 'aspect_ratio',
#        'movie_facebook_likes'],
#       dtype='object')

# %%
df=df.drop(columns=['Unnamed: 0'])
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron              723.000000     178.0
# 1     Color     Gore Verbinski              302.000000     169.0
# 2     Color         Sam Mendes              602.000000     148.0
# 3     Color  Christopher Nolan              813.000000     164.0
# 4     Color     Andrew Stanton              462.000000     132.0
# ...     ...                ...                     ...       ...
# 4549  Color   Neill Dela Llana               35.000000      80.0
# 4550  Color   Robert Rodriguez               56.000000      81.0
# 4551  Color    Anthony Vallone              322.146105      84.0
# 4552  Color       Edward Burns               14.000000      95.0
# 4553  Color           Jon Gunn               43.000000      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                         0.0                   855.0    Joel David Moore
# ...

# %%
# df.loc[:]['director_name']
df.loc[1][:]
# Out:
# color                                                                    Color
# director_name                                                   Gore Verbinski
# num_critic_for_reviews                                                   302.0
# duration                                                                 169.0
# director_facebook_likes                                                  563.0
# actor_3_facebook_likes                                                  1000.0
# actor_2_name                                                     Orlando Bloom
# actor_1_facebook_likes                                                 40000.0
# gross                                                              309404152.0
# genres                                                Action|Adventure|Fantasy
# actor_1_name                                                       Johnny Depp
# movie_title                          Pirates of the Caribbean: At World's End
# ...

# %%
df.loc[0:5][['movie_title','budget','imdb_score']]
# Out:
#                                  movie_title       budget  imdb_score
# 0                                    Avatar   237000000.0         7.9
# 1  Pirates of the Caribbean: At World's End   300000000.0         7.1
# 2                                   Spectre   245000000.0         6.8
# 3                     The Dark Knight Rises   250000000.0         8.5
# 4                               John Carter   263700000.0         6.6
# 5                              Spider-Man 3   258000000.0         6.2

# %%
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron              723.000000     178.0
# 1     Color     Gore Verbinski              302.000000     169.0
# 2     Color         Sam Mendes              602.000000     148.0
# 3     Color  Christopher Nolan              813.000000     164.0
# 4     Color     Andrew Stanton              462.000000     132.0
# ...     ...                ...                     ...       ...
# 4549  Color   Neill Dela Llana               35.000000      80.0
# 4550  Color   Robert Rodriguez               56.000000      81.0
# 4551  Color    Anthony Vallone              322.146105      84.0
# 4552  Color       Edward Burns               14.000000      95.0
# 4553  Color           Jon Gunn               43.000000      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                         0.0                   855.0    Joel David Moore
# ...

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df=df.drop(columns=['Unnamed: 0'])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12256\3192011523.py in <module>
# ----> 1 df=df.drop(columns=['Unnamed: 0'])
#       2 df
#
# c:\Users\Abhinav\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\Abhinav\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
df.iloc[0][1]
# Out:
# 'James Cameron'

# %%
index = df.columns.get_loc('director_name')
print(index)
df.iloc[:index]
# Out:
# 1
#    color  director_name  num_critic_for_reviews  duration  \
# 0  Color  James Cameron                   723.0     178.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
#
#   movie_facebook_likes
# 0                33000
#
# [1 rows x 28 columns]

# %%
df.sort_values(by=['imdb_score'],ascending=False).head(n=10).loc[:][['movie_title','imdb_score','title_year']]
# df.sort_values(by=['budget']).head().loc[:]['budget']
# Out:
#                                          movie_title  imdb_score  title_year
# 1864                       The Shawshank Redemption          9.3      1994.0
# 3293                                  The Godfather          9.2      1972.0
# 2714                         The Godfather: Part II          9.0      1974.0
# 65                                  The Dark Knight          9.0      2008.0
# 4416                                   12 Angry Men          8.9      1957.0
# 3197                                   Pulp Fiction          8.9      1994.0
# 327   The Lord of the Rings: The Return of the King          8.9      2003.0
# 4177                 The Good, the Bad and the Ugly          8.9      1966.0
# 1803                               Schindler's List          8.9      1993.0
# 96                                        Inception          8.8      2010.0

# %%
# val=df.dropna(inplace=True)
# val

# %%
df.groupby(['title_year'])['imdb_score','movie_title','budget'].max()
# Out:
# C:\Users\Abhinav\AppData\Local\Temp\ipykernel_19696\522994593.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['title_year'])['imdb_score','movie_title','budget'].max()
#             imdb_score                                        movie_title  \
# title_year
# 1916.0             8.0  Intolerance: Love's Struggle Throughout the Ages
# 1925.0             8.3                                    The Big Parade
# 1927.0             8.3                                        Metropolis
# 1929.0             8.0                               The Broadway Melody
# 1930.0             7.8                                     Hell's Angels
# ...                ...                                                ...
# 2012.0             8.5                                  Zero Dark Thirty
# 2013.0             8.4                                              Zulu
# ...

# %%
df.loc[1][movie_title]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3408\259217606.py in <module>
# ----> 1 df.loc[1][movie_title]
#       2 df
#
# NameError: name 'df' is not defined
