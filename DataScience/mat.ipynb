# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x = np.arange(17)
b = np.cos(2*x)
c = np.sin(2*x)

plt.plot(x,b)
plt.plot(x,c)
plt.show()

# %%
plt.scatter(x,b,marker='*')
plt.show()
plt.scatter(x,c)
plt.show()

# %% [markdown]
# Mean

# %%
n = np.arange(8)
m= np.arange(8,17)
mn = np.mean(n)
M = np.subtract(n,mn)
sq = np.square(M)
val1=np.sum(sq)/len(n)

val2 = np.sum(np.square(np.subtract(m, np.mean(m))))/len(m)
sum = val1+val2
sum/2
# Out:
# 5.958333333333334
